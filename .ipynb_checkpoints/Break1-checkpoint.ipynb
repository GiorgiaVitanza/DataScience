# %% [markdown]
# Exercise: Create a dataframe that contains the information about an hypothetical list of christmas presents you made
#
# Exercise: Create a dataframe with 1000 rows, columns "Gender" and "Height", exactly 500 males and 500 females, such that female's height average is roughly 168, and male's roughly 174

# %%
import pandas as pd

# %%
presents = ["libro", "giocattolo", "profumo", "cellulare", "orologio"]
names = ["Giorgia", "Veronica", "Michela", "Federica", "Andrea"]
df = pd.DataFrame({"presents":presents, "names":names})

# %%
df
# Out:
#      presents     names
# 0       libro   Giorgia
# 1  giocattolo  Veronica
# 2     profumo   Michela
# 3   cellulare  Federica
# 4    orologio    Andrea

# %%
import numpy as np

# %%
height_female = np.random.normal(loc= 168, scale = 10, size = 500)
height_male = np.random.normal(loc=  174, scale = 10, size = 500)
# Out:
# 500

# %%
df2 = pd.DataFrame({"gender":["male"]*500+["female"]*500, "height":list(height_male)+list(height_female)})

# %%
df2
# Out:
#      gender      height
# 0      male  173.070895
# 1      male  174.347853
# 2      male  185.636214
# 3      male  173.490734
# 4      male  158.465919
# ..      ...         ...
# 995  female  164.768805
# 996  female  160.835083
# 997  female  172.322536
# 998  female  167.906007
# 999  female  160.543993
#
# [1000 rows x 2 columns]

# %% [markdown]
# Exercise: Use the Titanic dataframe to calculate the average Age in each Pclass
#
# Exercise: Use the Titanic dataframe to calculate the number of survived that are named John

# %%
df = pd.read_csv('titanic.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.groupby('Pclass')['Age'].mean()
# Out:
# Pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: Age, dtype: float64

# %%
survived_john = df.query("Survived==1" and "Name.str.contains('John')")
survived_john
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 8              9         1       3
# 41            42         0       2
# 45            46         0       3
# 98            99         1       2
# 112          113         0       3
# 117          118         0       2
# 160          161         0       3
# 162          163         0       3
# 165          166         1       3
# 168          169         0       1
# 172          173         1       3
# 188          189         0       3
# 212          213         0       3
# 226          227         1       2
# 227          228         0       3
# 302          303         0       3
# 324          325         0       3
# 328          329         1       3
# 401          402         0       3
# 418          419         0       2
# 467          468         0       1
# 527          528         0       1
# 548          549         0       3
# 549          550         1       2
# ...
